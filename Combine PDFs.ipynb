# %%
from google.colab import drive
drive.mount('/content/drive')

# !ls '/content/drive/Shared drives'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 'Data Strategy CoE'  'Direct Sales Development Analytics Documentation'

# %%
pip install pyPDF2

# %%
import time
from datetime import date
from PyPDF2 import PdfFileMerger

# %%
merger = PdfFileMerger()

# %%
input3 = open("/content/drive/Shared drives/Direct Sales Development Analytics Documentation/2020 OKR.pdf", "rb")
input2 = open("/content/drive/Shared drives/Direct Sales Development Analytics Documentation/Direct Sales All lines of business Dashboard.pdf", "rb")

# %%
# add the first 3 pages of input1 document to output
merger.append(input3)

# %%
# append entire input3 document to the end of the output document
merger.append(input2)

# %%
# Write to an output PDF document
output = open("/content/drive/Shared drives/Direct Sales Development Analytics Documentation/xxxx.pdf", "wb")
merger.write(output)
